# %% [markdown]
# # Práctica 1 - Perceptron
# ## Preparación de entorno
# #### Importar librerías de código

# %% [markdown]
# Álvaro Chavarri, Daniel Ojeda, Carlos Vega y Lucía Gálvez

# %%
# from __future__ import division

import pandas as pd
import numpy as np
import random
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing
from matplotlib import pyplot as plt
from matplotlib import patches as patches
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
import copy 

# %matplotlib inline

# %% [markdown]
# #### Dataset que se va a utilizar para el entrenamiento

# %%
# Código para obtener el Dataset que se va a usar en el entrenamiento
file = 'infarto.csv'
#leemos los datasets
data = pd.read_csv(file, low_memory = False, encoding='ISO-8859-1', sep=';')

# %%
#borramos el id 
data = data.drop(['id'], axis=1)
#la edad la convertimos a numero entero
data['edad'] = data['edad'].astype(int)
#corregimos el nombre de la columna
data = data.rename(columns={'hipertensiÃ³n':'hipertension'})

# %%
data
# Out:
#          genero  edad  hipertension  enfermedad_coronaria casado  \
# 0     Masculino    67             0                     1     Si
# 1      Femenino    61             0                     0     Si
# 2     Masculino    80             0                     1     Si
# 3      Femenino    49             0                     0     Si
# 4      Femenino    79             1                     0     Si
# 5     Masculino    81             0                     0     Si
# 6     Masculino    74             1                     1     Si
# 7      Femenino    69             0                     0     No
# 8      Femenino    59             0                     0     Si
# 9      Femenino    78             0                     0     Si
# 10     Femenino    81             1                     0     Si
# 11     Femenino    61             0                     1     Si
# 12     Femenino    54             0                     0     Si
# ...
